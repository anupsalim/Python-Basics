# %% [markdown]
# <a href="https://colab.research.google.com/github/anupsalim/Python-Basics/blob/main/SecondDay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 10 > 5:
  print(10)
# Out:
# 10
